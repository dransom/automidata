# %% [markdown]
# # **Automatidata: Exploratory Data Anlysis**

# %% [markdown]
# This is the initial data exploration of the Automatidata data set. This data is taxi from New York ~2017.
#
# Additionally, there is some EDA that includes a Tableau visualization. For this taxi data, create a Tableau dashboard showing a New York City map of taxi/limo trips by month..
#
# This notebook is structured as a walk through the EDA of the data set.

# %% [markdown]
# **The purpose** of this project is to conduct exploratory data analysis on a provided data set. Your mission is to continue the investigation you began in C2 and perform further EDA on this data with the aim of learning more about the variables.
#
# **The goal** is to clean data set and create a visualization.
# <br/>
# *This project has 4 parts:*
#
# **Part 1:** Imports, links, and loading
#
# **Part 2:** Data Exploration & Cleaning
#
# **Part 3:** Building visualizations
#
# **Part 4:** Evaluate and share results

# %%
# Import packages and libraries
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Load dataset into dataframe
df = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv')

# %% [markdown]
# ## Step 1: Data exploration and cleaning
#
# Decide which columns are applicable
#
# The first step is to assess your data.
#
# Given our scenario, which data columns are most applicable?
# Which data columns can I eliminate, knowing they won’t solve our problem scenario?
#
# Consider functions that help you understand and structure the data.
#
# *    head()
# *    describe()
# *    info()
# *    groupby()
# *    sortby()
#
# What do you do about missing data (if any)?
#
# Are there data outliers? What are they and how might you handle them?
#
# What do the distributions of your variables tell you about the question you're asking or the problem you're trying to solve?

# %%
df.head()
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %% [markdown]
# There is no missing data according to the outputs above.

# %% [markdown]
# ## Step 2: Data visualization
#
# ### Select visualization type(s)
#
# The following charts will be helpful in exploring the data:
#
# * Box plot: helpful to determine outliers and where the bulk of the data resides in terms of `trip_distance`, `duration`, and `total_amount`.
# * Scatter plot: helpful to visualize trends, patterns, and outliers of important variables, such as `trip_distance`, and `total_amount`.
# * Bar chart: help to determine the average number of tirps per month, week, weekend, etc.

# %% [markdown]
# ### Boxplots

# %% [markdown]
# Perform a check for outliers on relevant columns such as trip distance and trip duration. Remember, some of the best ways to identify the presence of outliers in data are box plots and histograms.
#
# **Note:** Remember to convert your date columns to datetime in order to derive total trip duration.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
# Convert data columns to datetime
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  datetime64[ns]
#  3   tpep_dropoff_datetime  22699 non-null  datetime64[ns]
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %% [markdown]
# **trip distance**

# %%
# Create box plot of trip_distance
sns.boxplot(x = df.trip_distance, fliersize=1)
plt.xlabel('Trip Distance (miles)')
plt.title('Box Plot of Trip Distances')
# Out:
# Text(0.5, 1.0, 'Box Plot of Trip Distances')

# %%
# Create histogram of trip_distance
sns.histplot(x = df.trip_distance, bins = range(0, 26, 1))
plt.title('Histogram of Trip Distance')
plt.xlabel('Trip Distance (miles)')
plt.xlim(0)
# Out:
# (0.0, 26.25)

# %% [markdown]
# **Note:** The majority of the trips were less than 2 miles. The number of tripps falls steeply as the distance increases beyond 2-miles.

# %% [markdown]
# **total amount**

# %%
# Create box plot of total_amount
sns.boxplot(x = df.total_amount, fliersize=1)
plt.xlabel('Total Fare Amount (USD)')
plt.title('Box Plot of Total Fare Amount')
# Out:
# Text(0.5, 1.0, 'Box Plot of Total Fare Amount')

# %%
# Create histogram of total_amount
ax = sns.histplot(x = df.total_amount, bins = range(0, 150, 5))
plt.title('Histogram of Total Fare Amount')
plt.xlabel('Total Amount (USD)')
ax.set_xticks(range(0,150,5))
ax.set_xticklabels(range(0,150,5))
plt.xticks(rotation = 45)
plt.xlim(0)
# Out:
# (0.0, 152.25)

# %% [markdown]
# **Note:** The total cost of each has a distribution that skews right, with most falling in the 5-15 USD range.

# %% [markdown]
# **tip amount**

# %%
# Create box plot of tip_amount
sns.boxplot(x = df.tip_amount, fliersize=1)
plt.xlabel('Tip Amount Amount (USD)')
plt.title('Box Plot of Tip Amount')
# Out:
# Text(0.5, 1.0, 'Box Plot of Tip Amount')

# %%
# Create histogram of tip_amount
ax = sns.histplot(x = df.tip_amount, bins = range(0, 26, 1))
plt.title('Histogram of Tip Amount')
plt.xlabel('Tip Amount (USD)')
ax.set_xticks(range(0,28,2))
ax.set_xticklabels(range(0,28,2))
plt.xlim(0)
# Out:
# (0.0, 26.25)

# %% [markdown]
# **Note:** The distribution of the tip amount of skewed right, with nearly all the tips in the 0-3 USD range.

# %% [markdown]
# **tip_amount by vendor**

# %%
# Create histogram of tip_amount by vendor
ax = sns.histplot(data = df,
                  x = df.tip_amount,
                  bins = range(0, 26, 1),
                  hue='VendorID',
                  multiple = 'stack',
                  palette = 'pastel'
                 )
plt.title('Histogram of Tip Amount by Vendor ID')
plt.xlabel('Tip Amount (USD)')
ax.set_xticks(range(0,28,2))
ax.set_xticklabels(range(0,28,2))
plt.xlim(0)
# Out:
# (0.0, 26.25)

# %% [markdown]
# **Note:** Separating the tips out by vendor shows there is no real difference in the distribution of tips between the two vendors.
#
# Next, zoom in on the upper end of the range of tips to check whether vendor one gets noticeably more of the most generous tips.

# %%
# Create histogram of tip_amount by vendor for tips > $10 
tips_over_10 = df[df.tip_amount > 10]
ax = sns.histplot(data = tips_over_10,
                  x = tips_over_10.tip_amount,
                  bins = range(10, 26, 1),
                  hue='VendorID',
                  multiple = 'stack',
                  palette = 'pastel'
                 )
plt.title('Histogram of Tip Amount by Vendor ID')
plt.xlabel('Tip Amount (USD)')
ax.set_xticks(range(10,28,2))
ax.set_xticklabels(range(10,28,2))
plt.xlim(10)
# Out:
# (10.0, 26.0)

# %% [markdown]
# **Note:** The distribution of tips is proportioned between the two vendors even at higher ranges.

# %% [markdown]
# **Mean tips by passenger count**
#
# Examine the unique values in the `passenger_count` column.

# %%
df.passenger_count.value_counts()
# Out:
# 1    16117
# 2     3305
# 5     1143
# 3      953
# 6      693
# 4      455
# 0       33
# Name: passenger_count, dtype: int64

# %% [markdown]
# **Note:** Almost all the rides just have a 1 passenger. Some rides have 0 passengers, which does not make sense.

# %%
# Calculate mean tips by passenger_count
mean_tips_by_passenger_count = df.groupby('passenger_count')['tip_amount'].mean()
mean_tips_by_passenger_count
# Out:
# passenger_count
# 0    2.135758
# 1    1.848920
# 2    1.856378
# 3    1.716768
# 4    1.530264
# 5    1.873185
# 6    1.720260
# Name: tip_amount, dtype: float64

# %%
type(mean_tips_by_passenger_count)
# Out:
# pandas.core.series.Series

# %%
mean_tips_by_passenger_count.index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64', name='passenger_count')

# %%
mean_tips_by_passenger_count.values
# Out:
# array([2.13575758, 1.84892039, 1.85637821, 1.7167681 , 1.53026374,
#        1.8731846 , 1.72025974])

# %%
mean_tips_by_passenger_count = mean_tips_by_passenger_count[1:]
mean_tips_by_passenger_count
# Out:
# passenger_count
# 1    1.848920
# 2    1.856378
# 3    1.716768
# 4    1.530264
# 5    1.873185
# 6    1.720260
# Name: tip_amount, dtype: float64

# %%
mean_tips_by_passenger_count = mean_tips_by_passenger_count.to_frame(name = 'tip_mean').reset_index()
type(mean_tips_by_passenger_count)
# Out:
# pandas.core.frame.DataFrame

# %%
# Create bar plot for mean tips by passenger count

global_mean = df.tip_amount.mean()

plt.figure(figsize=(12,7))

# Make pallette 
pal = sns.color_palette("Greens_d", len(mean_tips_by_passenger_count))
rank = mean_tips_by_passenger_count.tip_mean.argsort().argsort()

ax = sns.barplot(data = mean_tips_by_passenger_count,
                x = 'passenger_count',
                y = 'tip_mean',
                palette=np.array(pal[::-1])[rank])
plt.xlabel('Passenger Count')
plt.ylabel('Mean Tip (USD)')

ax.axhline(df['tip_amount'].mean(), ls='--', color='red', label='global mean')
ax.legend();

# %% [markdown]
# **Note:** The mean tip does not vary between the amount of passengers.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  datetime64[ns]
#  3   tpep_dropoff_datetime  22699 non-null  datetime64[ns]
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %% [markdown]
# **Create month and day columns**

# %%
# Create a month column
df['month'] =  df.tpep_dropoff_datetime.dt.month_name()

# Create a day column
df['day'] = df.tpep_dropoff_datetime.dt.day_name()

df.head()
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0    24870114         2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1    35634249         1  2017-04-11 14:53:28   2017-04-11 15:19:58
# 2   106203690         1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 3    38942136         2  2017-05-07 13:17:59   2017-05-07 13:48:14
# 4    30841670         2  2017-04-15 23:32:20   2017-04-15 23:49:03
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           100           231             1         13.0    0.0      0.5
# ...

# %% [markdown]
# **Plot total ride count by month**
#
# Begin by calculating total ride count by month.

# %%
# Get total number of rides for each month
#==> ENTER YOUR CODE HERE
total_rides_by_month = df.month.value_counts()
total_rides_by_month
# Out:
# March        2049
# October      2026
# April        2019
# May          2012
# January      1996
# June         1963
# December     1863
# November     1844
# February     1770
# September    1734
# August       1725
# July         1698
# Name: month, dtype: int64

# %%
type(total_rides_by_month)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Reorder the results to put the months in calendar order.

# %%
# Reorder the monthly ride list so months go in order
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
         'August', 'September', 'October', 'November', 'December']

total_rides_by_month = total_rides_by_month.reindex(index = month_order)
total_rides_by_month
# Out:
# January      1996
# February     1770
# March        2049
# April        2019
# May          2012
# June         1963
# July         1698
# August       1725
# September    1734
# October      2026
# November     1844
# December     1863
# Name: month, dtype: int64

# %%
# Create a bar plot of total rides per month
plt.figure(figsize=(12,7))
sns.barplot(x = total_rides_by_month.index,
                y = total_rides_by_month.values)
plt.title('Total Rides per Month')
plt.xlabel('Month')
plt.ylabel('Total Rides')
# Out:
# Text(0, 0.5, 'Total Rides')

# %% [markdown]
# **Note:** Monthly rides are fairly consistent, with some dips in the latter part of the summer and in February.

# %% [markdown]
# **Plot total ride count by day**
#
# Repeat the above process, but now calculate the total rides by day of the week.

# %%
# Repeat the above process, this time for rides by day
total_rides_by_day = df.day.value_counts()

day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

total_rides_by_day = total_rides_by_day.reindex(index = day_order)

total_rides_by_day
# Out:
# Monday       2940
# Tuesday      3192
# Wednesday    3380
# Thursday     3392
# Friday       3417
# Saturday     3352
# Sunday       3026
# Name: day, dtype: int64

# %%
# Create bar plot for ride count by day
plt.figure(figsize=(12,7))
sns.barplot(x = total_rides_by_day.index,
                y = total_rides_by_day.values)
plt.title('Total Rides per Day')
plt.xlabel('Day of the Week')
plt.ylabel('Total Rides')
# Out:
# Text(0, 0.5, 'Total Rides')

# %% [markdown]
# **Note:** Wednesday - Saturday have the highest amount of rides with Sunday & Monday being the lowest.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  datetime64[ns]
#  3   tpep_dropoff_datetime  22699 non-null  datetime64[ns]
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %% [markdown]
# **Plot total revenue by day of the week**
#
# Repeat the above process, but now calculate the total revenue by day of the week.

# %%
# Repeat the process, this time for total revenue by day
total_amount_by_day = df.groupby('day').total_amount.sum()

total_amount_by_day = total_amount_by_day.reindex(index = day_order)

total_amount_by_day
# Out:
# day
# Monday       49825.91
# Tuesday      52375.77
# Wednesday    55297.77
# Thursday     56736.27
# Friday       56171.27
# Saturday     50956.20
# Sunday       48868.90
# Name: total_amount, dtype: float64

# %%
# Create bar plot of total revenue by day
plt.figure(figsize=(12,7))

sns.barplot(x = total_amount_by_day.index,
            y = total_amount_by_day.values)

plt.title('Total Revenue by Day')
plt.xlabel('Day of the Week')
plt.ylabel('Revenue (USD)')
# Out:
# Text(0, 0.5, 'Revenue (USD)')

# %% [markdown]
# **Note:** Thursday has the highest gross revenue with Sunday and Monday being the lowest.

# %% [markdown]
# **Plot total revenue by month**

# %%
# Repeat the process, this time for total revenue by month
total_amount_by_month = df.groupby('month').total_amount.sum()

total_amount_by_month = total_amount_by_month.reindex(index = month_order)

total_amount_by_month
# Out:
# month
# January      31721.95
# February     28951.19
# March        33085.89
# April        32012.54
# May          33815.02
# June         32914.48
# July         26626.68
# August       27770.12
# September    28206.38
# October      33045.67
# November     30820.60
# December     31261.57
# Name: total_amount, dtype: float64

# %%
# Create a bar plot of total revenue by month
plt.figure(figsize=(12,7))

sns.barplot(x = total_amount_by_month.index,
            y = total_amount_by_month.values)

plt.title('Total Revenue by Month')
plt.xlabel('Month')
plt.ylabel('Revenue (USD)')
# Out:
# Text(0, 0.5, 'Revenue (USD)')

# %% [markdown]
# **Note:** Monthly revenue shows the same pattern as monthly rides. There are dips in the latter of half of the summer (July - Sept) and one in February.

# %% [markdown]
# #### Scatter plot

# %% [markdown]
# This visualization was created in Tableau. The data was easier to maniulate and present in Tableau. [Here is a link](https://public.tableau.com/app/profile/dane.ransom/viz/TLC2017_16901460697070/TripDistancevsTotalAmount) to the public project. A few outliers were removed to better illustrate the data.

# %%
# Save any changes to data as a CSV
df.to_csv('images/2017_Yellow_Taxi_Trip_Data_Formatted.csv')

# %% [markdown]
# Scatterplot created in Tableau Public
# ![Trip Distance vs Total Amount.png](attachment:6d073e2b-dbc8-4a0d-84e5-c4d87290d8de.png)

# %% [markdown]
# **Note:** It is clearly visible that there are some trips with no distance but there was a fare amount.

# %% [markdown]
# **Plot mean trip distance by drop-off location**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  datetime64[ns]
#  3   tpep_dropoff_datetime  22699 non-null  datetime64[ns]
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
# Get number of unique drop-off location IDs
df.DOLocationID.nunique()
# Out:
# 216

# %%
# Calculate the mean trip distance for each drop-off location
drop_off_mean_trip_distance = df.groupby('DOLocationID').trip_distance.mean()

# Sort the results in descending order by mean trip distance
drop_off_mean_trip_distance = drop_off_mean_trip_distance.sort_values()
drop_off_mean_trip_distance
# Out:
# DOLocationID
# 207     1.200000
# 193     1.390556
# 237     1.555494
# 234     1.727806
# 137     1.818852
#          ...
# 51     17.310000
# 11     17.945000
# 210    20.500000
# 29     21.650000
# 23     24.275000
# Name: trip_distance, Length: 216, dtype: float64

# %%
# Create a bar plot of mean trip distances by drop-off location in ascending order by distance
plt.figure(figsize=(14,6))

ax = sns.barplot(x = drop_off_mean_trip_distance.index,
            y = drop_off_mean_trip_distance.values,
           order = drop_off_mean_trip_distance.index)

ax.set_xticklabels([])
ax.set_xticks([])

plt.xlabel('Drop Location ID')
plt.ylabel('Mean Trip Distance (miles)')
plt.title('Mean trip distance by drop-off location', fontsize=16);

# %% [markdown]
# **Note:** This plot is similar to the cumulative density function of a normal distrition. It could mean that the drop off locations are evenly distributed over the terrain. The data does not contain geographic coordinates so there was no obvious way to test for the distribution of locations.
#
# To test if the drop off locations are normally distributed, we can perform the following test:
#
# 1. Create a sample of coordinates from a normal distribution &mdash; in this case 1,500 pairs of points from a normal distribution with a mean of 10 and a standard deviation of 52. Calculate thee distance between each pair of coordinates.
# 3. Group the coordinates by endpoint and calculate the mean distance between that endpoint and all other points it was paired with.
# 4. Plot the mean distance for each unique endpoint.

# %%
#1. Generate random points on a 2D plane from a normal distribution
test = np.round(np.random.normal(10, 5, (3000, 2)), 1)
midway = int(len(test)/2) # Calculate midpoint
start = test[:midway] # Isolate first half of the array 
end = test[midway:] # Isolate second half of the array


# 2. Calculate Euclidean distances between points in first half and second half of array
distances = (start - end) ** 2
distances = distances.sum(axis = 1)
distances = np.sqrt(distances)

# 3. Group the coordinates by "drop-off location", compute mean distance
test_df = pd.DataFrame({'start': [tuple(x) for x in start.tolist()],
                   'end': [tuple(x) for x in end.tolist()],
                   'distance': distances})
data = test_df[['end', 'distance']].groupby('end').mean()
data = data.sort_values(by='distance')

# 4. Plot the mean distance between each endpoint ("drop-off location") and all points it connected to
plt.figure(figsize=(14,6))
ax = sns.barplot(x=data.index,
                 y=data['distance'],
                 order=data.index)
ax.set_xticklabels([])
ax.set_xticks([])
ax.set_xlabel('Endpoint')
ax.set_ylabel('Mean distance to all other points')
ax.set_title('Mean distance between points taken randomly from normal distribution');

# %% [markdown]
# **Note:** The curve described by this graph is nearly identical to that of the mean distance traveled by each taxi ride to each drop-off location. This reveals that the drop-off locations in the taxi dataset are evenly distributed geographically. Note, however, that this does not mean that there was an even distrubtion of rides to each drop-off point. Examine this next.

# %% [markdown]
# **Histogram of rides by drop-off location**

# %% [markdown]
# First, check to whether the drop-off locations IDs are consecutively numbered. For instance, does it go 1, 2, 3, 4..., or are some numbers missing (e.g., 1, 3, 4...). If numbers aren't all consecutive, the histogram will look like some locations have very few or no rides when in reality there's no bar because there's no location.

# %%
# Check if all drop-off locations are consecutively numbered
df.DOLocationID.max() - len(set(df.DOLocationID))
# Out:
# 49

# %% [markdown]
# To eliminate the spaces in the historgram that these missing numbers would create, sort the unique drop-off location values, then convert them to strings. This will make the histplot function display all bars directly next to each other.

# %%
plt.figure(figsize=(16,4))

# DOLocationID column is numeric, so sort in ascending order
sorted_dropoffs = df.DOLocationID.sort_values()

# Convert to string
sorted_dropoffs = sorted_dropoffs.astype('str')

# Plot
sns.histplot(sorted_dropoffs,
            bins = range(0, df.DOLocationID.max()+1, 1));

plt.xticks([])
plt.xlabel('Drop off Locations')
plt.title('Histogram of rides by Drop Off Location', fontsize = 16);

# %% [markdown]
# Out of all the drop off locations, a disproportionate amount seem to be located as specific locations and the rest get relatively few drop offs. The high drop off locations are most likely busy areas such as tourist destinations or work areas.

# %% [markdown]
# ## Conclusion
#
# As a result of the conducted exploratory data analysis, the Automatidata data considered trip distance and total amount as key variables to depict a taxi cab ride. The scatter plot was created in Tableau to enhance the provided visualization.
#
# **The Problem:** After running initial exploratory data analysis (EDA) on a sample of the data provided by New York City TLC, it is clear that some of the data will prove an obstacle for accurate ride fare prediction. Namely, trips that have a total cost entered, but a total distance of “0.” At this point, our analysis indicates these to be anomalies or outliers that need to be factored into the algorithm or removed completely.
#
# **Proposed solution:** After analysis, we recommend removing outliers with a total distanced recorded of 0.
#
# **Next steps:**
#
# * Determine any unusual data points that could pose a problem for future analysis in predicting trip fares. For example, locations that have longer durations.
# * Determine the variables that have the largest impact on trip fares.
# * Filter down to consider the most relevant variables for running regression, statistical analysis, and parameter tuning.
